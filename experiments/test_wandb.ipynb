# %%
import wandb
import os
os.environ["WANDB__REQUIRE_LEGACY_SERVICE"] = "true"
wandb.login()
# Out:
# True

# %%
sweep_config = {
    'method': 'grid',
    'name': 'sweep',
    'metric': {
        'goal': 'maximize',
        'name': 'accuracy'
    },
    'parameters': {
        'learning_rate': {
            'values': [0.001, 0.01, 0.1]
        },
        'batch_size': {
            'values': [16, 32, 64]
        },
        'epochs': {
            'values': [5, 10, 20]
        }
    }
}

sweep_id = wandb.sweep(sweep=sweep_config, project="test-project")
# Out:
# Create sweep with ID: vrcupohe
# Sweep URL: https://wandb.ai/mutyuu/test-project/sweeps/vrcupohe

# %%
wandb.init(
    project="test-project", 
    entity="your-entity",
    )
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File ~/miniconda3/envs/CS336/lib/python3.13/asyncio/tasks.py:507, in wait_for(fut, timeout)
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File ~/miniconda3/envs/CS336/lib/python3.13/asyncio/locks.py:213, in Event.wait(self)
#     212 try:
# --> 213     await fut
#     214     return True
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# ...
